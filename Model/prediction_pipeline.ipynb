# %%
import tensorflow as tf
from   tensorflow import keras 
import numpy as np 
import pickle
from PIL import Image 
import seaborn as sn
import matplotlib.pyplot as plt

# %%
with open('model.pickle','rb') as f : 
    model = pickle.load(f)

# %%
def preprocessing(image):
    new_image  = Image.open(image).convert("L")
    new_image  = new_image.resize((28 , 28))
    new_image  = np.array(new_image)
    new_image  = new_image / 255
    new_image_flatterned = new_image.reshape(1,28*28)
    return new_image_flatterned

# %%
def predict(new_image_flatterned):
    prediction = model.predict(new_image_flatterned)
    max_pred = max(prediction)
    return max_pred

# %%
image = "../Samples/7.png"

new_image_flatterned = preprocessing(image)
predict(new_image_flatterned)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# array([2.1991809e-07, 6.7779132e-16, 2.5240777e-07, 1.0000000e+00,
#        3.7941460e-20, 1.0000000e+00, 3.3825313e-04, 9.9999934e-01,
#        6.5257563e-03, 3.9022222e-10], dtype=float32)

# %%
print(new_image_flatterned.shape)
# Out:
# (1, 784)

# %%
plt.imshow(new_image.reshape(28,28), cmap="gray")

# %%
image
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 image.shape()
#
# AttributeError: 'str' object has no attribute 'shape'
